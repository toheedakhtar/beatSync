# %%
import pandas as pd

# %%
songs_df = pd.read_csv('../dataset/SpotifySongs.csv')
songs_df.head(5)
# Out:
#                                             SongName         ArtistName  \
# 0                                         Saiyaan Ji  Yo Yo Honey Singh
# 1                                            Falling      Trevor Daniel
# 2                                             Shayad             Pritam
# 3  Malang (Title Track) [From "Malang - Unleash T...         Ved Sharma
# 4                      Genda Phool (feat. Payal Dev)            Badshah
#
#    Popularity  Danceability  Energy  Key  Loudness  Mode  Speechiness  \
# 0          62         0.896   0.678    0    -2.546     0       0.0815
# 1          84         0.785   0.431   10    -8.756     0       0.0364
# 2          72         0.483   0.468    8    -7.642     1       0.0341
# 3          68         0.384   0.728    7    -6.503     0       0.0623
# 4          67         0.955   0.538    1    -8.394     1       0.0734
#
#    Acousticness  Instrumentalness  Liveness  Valence    Tempo  Duration_ms
# ...

# %%
songs_df.shape
# Out:
# (3731, 15)

# %%
songs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3731 entries, 0 to 3730
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SongName          3731 non-null   object
#  1   ArtistName        3731 non-null   object
#  2   Popularity        3731 non-null   int64
#  3   Danceability      3731 non-null   float64
#  4   Energy            3731 non-null   float64
#  5   Key               3731 non-null   int64
#  6   Loudness          3731 non-null   float64
#  7   Mode              3731 non-null   int64
#  8   Speechiness       3731 non-null   float64
#  9   Acousticness      3731 non-null   float64
#  10  Instrumentalness  3731 non-null   float64
#  11  Liveness          3731 non-null   float64
#  12  Valence           3731 non-null   float64
#  13  Tempo             3731 non-null   float64
#  14  Duration_ms       3731 non-null   int64
# dtypes: float64(9), int64(4), object(2)
# memory usage: 437.4+ KB

# %%
songs_df.isnull().any()
# Out:
# SongName            False
# ArtistName          False
# Popularity          False
# Danceability        False
# Energy              False
# Key                 False
# Loudness            False
# Mode                False
# Speechiness         False
# Acousticness        False
# Instrumentalness    False
# Liveness            False
# Valence             False
# Tempo               False
# Duration_ms         False
# dtype: bool

# %%
songs_df.describe()
# Out:
#         Popularity  Danceability       Energy          Key     Loudness  \
# count  3731.000000   3731.000000  3731.000000  3731.000000  3731.000000
# mean     65.066470      0.605458     0.586561     4.884749    -7.610220
# std      23.497576      0.156735     0.217523     3.647925     5.043379
# min       0.000000      0.085800     0.005020     0.000000   -34.991000
# 25%      56.000000      0.510000     0.453000     1.000000    -8.426000
# 50%      73.000000      0.630000     0.628000     5.000000    -6.237000
# 75%      81.000000      0.721000     0.754000     8.000000    -4.884000
# max      97.000000      0.970000     0.990000    11.000000    -1.190000
#
#               Mode  Speechiness  Acousticness  Instrumentalness     Liveness  \
# count  3731.000000  3731.000000   3731.000000       3731.000000  3731.000000
# mean      0.584294     0.084800      0.313658          0.076124     0.166752
# std       0.492909     0.087001      0.308686          0.233818     0.118579
# ...

# %%
songs_df_cpy = songs_df

# %%
duration_s = (songs_df['Duration_ms'] / 1000)
songs_df_cpy['Duration_s'] = duration_s.round(decimals=1)
songs_df_cpy
# Out:
#                                                SongName         ArtistName  \
# 0                                            Saiyaan Ji  Yo Yo Honey Singh
# 1                                               Falling      Trevor Daniel
# 2                                                Shayad             Pritam
# 3     Malang (Title Track) [From "Malang - Unleash T...         Ved Sharma
# 4                         Genda Phool (feat. Payal Dev)            Badshah
# ...                                                 ...                ...
# 3726                                      Back To Black      Amy Winehouse
# 3727                           Where Do We Go From Here    Charles Bradley
# 3728                          Way down We Go - Stripped              KALEO
# 3729                                 Let's Talk It Over         Lee Fields
# 3730                       The Gentle Rain - RJD2 Remix    Astrud Gilberto
#
# ...

# %%
songs_id = [i for i, name in enumerate(songs_df['SongName'], start=1)]
songs_df_cpy['id'] = songs_id
# Out:
#                                             SongName         ArtistName  \
# 0                                         Saiyaan Ji  Yo Yo Honey Singh
# 1                                            Falling      Trevor Daniel
# 2                                             Shayad             Pritam
# 3  Malang (Title Track) [From "Malang - Unleash T...         Ved Sharma
# 4                      Genda Phool (feat. Payal Dev)            Badshah
#
#    Popularity  Danceability  Energy  Key  Loudness  Mode  Speechiness  \
# 0          62         0.896   0.678    0    -2.546     0       0.0815
# 1          84         0.785   0.431   10    -8.756     0       0.0364
# 2          72         0.483   0.468    8    -7.642     1       0.0341
# 3          68         0.384   0.728    7    -6.503     0       0.0623
# 4          67         0.955   0.538    1    -8.394     1       0.0734
#
#    Acousticness  Instrumentalness  Liveness  Valence    Tempo  Duration_ms  \
# ...

# %%
songs_df_cpy = songs_df_cpy.drop(['SongName', 'ArtistName'], axis=1)
songs_df_cpy.head()
# Out:
#    Popularity  Danceability  Energy  Key  Loudness  Mode  Speechiness  \
# 0          62         0.896   0.678    0    -2.546     0       0.0815
# 1          84         0.785   0.431   10    -8.756     0       0.0364
# 2          72         0.483   0.468    8    -7.642     1       0.0341
# 3          68         0.384   0.728    7    -6.503     0       0.0623
# 4          67         0.955   0.538    1    -8.394     1       0.0734
#
#    Acousticness  Instrumentalness  Liveness  Valence    Tempo  Duration_ms  \
# 0        0.0137          0.000041    0.1100    0.604  130.024       205450
# 1        0.1230          0.000000    0.0887    0.236  127.085       159382
# 2        0.7850          0.000000    0.1520    0.319  135.864       247941
# 3        0.3290          0.000018    0.3290    0.311  156.396       287374
# 4        0.1320          0.001460    0.0704    0.837  116.977       170769
#
#    Duration_s  id
# 0       205.4   1
# 1       159.4   2
# 2       247.9   3
# ...
